# %%
class Gato:
    
    def __init__(self, nombre:str="Michi", color:str="naranja", edad:int=1):
        self.nombre = nombre
        self.color = color
        self.edad = edad

    def maullar(self):
        print("Meow")

# %%
michi1 = Gato()

# %%
type(michi1)
# Out:
# __main__.Gato

# %%
isinstance(1, int)
# Out:
# True

# %%
isinstance("hola mundo", str)
# Out:
# True

# %%
isinstance(michi1, Gato)
# Out:
# True

# %%
issubclass(Gato, object)
# Out:
# True

# %%
dir(michi1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'color',
#  'edad',
#  'maullar',
#  'nombre']

# %%
print(michi1)

# %%
michi1.maullar()
# Out:
# Meow
